# %%
import pandas as pd
import numpy as np
import sqlite3 as sql
import matplotlib.pyplot as plt
import seaborn as sns

# %%
database ="Chinook_Sqlite.db"
connection = sql.connect(database)

# %% [markdown]
# # Data Cleaning

# %%
Table1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 347 entries, 0 to 346
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   AlbumId   347 non-null    int64
#  1   Title     347 non-null    object
#  2   ArtistId  347 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 8.3+ KB

# %%
Table1.isna()
# Out:
#      AlbumId  Title  ArtistId
# 0      False  False     False
# 1      False  False     False
# 2      False  False     False
# 3      False  False     False
# 4      False  False     False
# ..       ...    ...       ...
# 342    False  False     False
# 343    False  False     False
# 344    False  False     False
# 345    False  False     False
# 346    False  False     False
#
# [347 rows x 3 columns]

# %%
Table3.isna()
# Out:
#     CustomerId  FirstName  LastName  Company  Address   City  State  Country  \
# 0        False      False     False    False    False  False  False    False
# 1        False      False     False     True    False  False   True    False
# 2        False      False     False     True    False  False  False    False
# 3        False      False     False     True    False  False   True    False
# 4        False      False     False    False    False  False   True    False
# 5        False      False     False     True    False  False   True    False
# 6        False      False     False     True    False  False   True    False
# 7        False      False     False     True    False  False   True    False
# 8        False      False     False     True    False  False   True    False
# 9        False      False     False    False    False  False  False    False
# 10       False      False     False    False    False  False  False    False
# ...

# %%
Table5.isna()
# Out:
#     GenreId   Name
# 0     False  False
# 1     False  False
# 2     False  False
# 3     False  False
# 4     False  False
# 5     False  False
# 6     False  False
# 7     False  False
# 8     False  False
# 9     False  False
# 10    False  False
# 11    False  False
# 12    False  False
# 13    False  False
# 14    False  False
# 15    False  False
# 16    False  False
# 17    False  False
# 18    False  False
# 19    False  False
# 20    False  False
# 21    False  False
# 22    False  False
# 23    False  False
# 24    False  False

# %% [markdown]
# # Table

# %%
query= '''select Name,type  from sqlite_master where type='table' '''

# %%
df= pd.read_sql_query(query ,connection)
df
# Out:
#              name   type
# 0           Album  table
# 1          Artist  table
# 2        Customer  table
# 3        Employee  table
# 4           Genre  table
# 5         Invoice  table
# 6     InvoiceLine  table
# 7       MediaType  table
# 8        Playlist  table
# 9   PlaylistTrack  table
# 10          Track  table

# %%
Table1 = '''select * from album'''
Table1= pd.read_sql_query(Table1 ,connection)
Table1.head()
# Out:
#    AlbumId                                  Title  ArtistId
# 0        1  For Those About To Rock We Salute You         1
# 1        2                      Balls to the Wall         2
# 2        3                      Restless and Wild         2
# 3        4                      Let There Be Rock         1
# 4        5                               Big Ones         3

# %%
Table2 = '''select * from Artist'''
Table2= pd.read_sql_query(Table2 ,connection)
Table2.head()
# Out:
#    ArtistId               Name
# 0         1              AC/DC
# 1         2             Accept
# 2         3          Aerosmith
# 3         4  Alanis Morissette
# 4         5    Alice In Chains

# %%
Table3 = '''select * from customer'''
Table3= pd.read_sql_query(Table3 ,connection)
Table3.head()
# Out:
#    CustomerId  FirstName     LastName  \
# 0           1       Luís    Gonçalves
# 1           2     Leonie       Köhler
# 2           3   François     Tremblay
# 3           4      Bjørn       Hansen
# 4           5  František  Wichterlová
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                  JetBrains s.r.o.
#
#                            Address                 City State         Country  \
# 0  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP          Brazil
# 1          Theodor-Heuss-Straße 34            Stuttgart  None         Germany
# 2                1498 rue Bélanger             Montréal    QC          Canada
# 3                 Ullevålsveien 14                 Oslo  None          Norway
# ...

# %%
Table4 = '''select * from Employee'''
Table4= pd.read_sql_query(Table4 ,connection)
Table4.head()
# Out:
#    EmployeeId LastName FirstName                Title  ReportsTo  \
# 0           1    Adams    Andrew      General Manager        NaN
# 1           2  Edwards     Nancy        Sales Manager        1.0
# 2           3  Peacock      Jane  Sales Support Agent        2.0
# 3           4     Park  Margaret  Sales Support Agent        2.0
# 4           5  Johnson     Steve  Sales Support Agent        2.0
#
#              BirthDate             HireDate              Address      City  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00  11120 Jasper Ave NW  Edmonton
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00         825 8 Ave SW   Calgary
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00        1111 6 Ave SW   Calgary
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00     683 10 Street SW   Calgary
# 4  1965-03-03 00:00:00  2003-10-17 00:00:00         7727B 41 Ave   Calgary
#
#   State Country PostalCode              Phone                Fax  \
# ...

# %%
Table5 = '''select *from Genre'''
Table5= pd.read_sql_query(Table5 ,connection)
Table5.head()
# Out:
#    GenreId                Name
# 0        1                Rock
# 1        2                Jazz
# 2        3               Metal
# 3        4  Alternative & Punk
# 4        5       Rock And Roll

# %%
Table6 = '''select * from invoiceline'''
Table6= pd.read_sql_query(Table6 ,connection)
Table6.head()
# Out:
#    InvoiceLineId  InvoiceId  TrackId  UnitPrice  Quantity
# 0              1          1        2       0.99         1
# 1              2          1        4       0.99         1
# 2              3          2        6       0.99         1
# 3              4          2        8       0.99         1
# 4              5          2       10       0.99         1

# %%
Table7 = '''select * from Invoice'''
Table7= pd.read_sql_query(Table7 ,connection)
Table7.head()
# Out:
#    InvoiceId  CustomerId          InvoiceDate           BillingAddress  \
# 0          1           2  2009-01-01 00:00:00  Theodor-Heuss-Straße 34
# 1          2           4  2009-01-02 00:00:00         Ullevålsveien 14
# 2          3           8  2009-01-03 00:00:00          Grétrystraat 63
# 3          4          14  2009-01-06 00:00:00           8210 111 ST NW
# 4          5          23  2009-01-11 00:00:00          69 Salem Street
#
#   BillingCity BillingState BillingCountry BillingPostalCode  Total
# 0   Stuttgart         None        Germany             70174   1.98
# 1        Oslo         None         Norway              0171   3.96
# 2    Brussels         None        Belgium              1000   5.94
# 3    Edmonton           AB         Canada           T6G 2C7   8.91
# 4      Boston           MA            USA              2113  13.86

# %%
Tabl8 = '''select * from MediaType'''
Tabl8= pd.read_sql_query(Tabl8 ,connection)
Tabl8.head()
# Out:
#    MediaTypeId                         Name
# 0            1              MPEG audio file
# 1            2     Protected AAC audio file
# 2            3  Protected MPEG-4 video file
# 3            4     Purchased AAC audio file
# 4            5               AAC audio file

# %%
Tabl9 = '''select * from Playlist'''
Tabl9= pd.read_sql_query(Tabl9 ,connection)
Tabl9.head()
# Out:
#    PlaylistId        Name
# 0           1       Music
# 1           2      Movies
# 2           3    TV Shows
# 3           4  Audiobooks
# 4           5  90’s Music

# %%
Tabl10 = '''select * from PlaylistTrack'''
Tabl10= pd.read_sql_query(Tabl10 ,connection)
Tabl10.head()
# Out:
#    PlaylistId  TrackId
# 0           1     3402
# 1           1     3389
# 2           1     3390
# 3           1     3391
# 4           1     3392

# %%
Tabl11 = '''select * from Track'''
Tabl11= pd.read_sql_query(Tabl11 ,connection)
Tabl11.head()
# Out:
#    TrackId                                     Name  AlbumId  MediaTypeId  \
# 0        1  For Those About To Rock (We Salute You)        1            1
# 1        2                        Balls to the Wall        2            2
# 2        3                          Fast As a Shark        3            2
# 3        4                        Restless and Wild        3            2
# 4        5                     Princess of the Dawn        3            2
#
#    GenreId                                           Composer  Milliseconds  \
# 0        1          Angus Young, Malcolm Young, Brian Johnson        343719
# 1        1                                               None        342562
# 2        1  F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619
# 3        1  F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...        252051
# 4        1                         Deaffy & R.A. Smith-Diesel        375418
#
#       Bytes  UnitPrice
# 0  11170334       0.99
# ...

# %% [markdown]
# # Analyzing top countries by more customers and sales

# %%
query1 = '''  SELECT C.COUNTRY,    COUNT( DISTINCT C.CUSTOMERID) as numـcustomers  ,sum(total)
  FROM CUSTOMER C
  JOIN INVOICE I ON C.CUSTOMERID = I.CUSTOMERID
  GROUP BY COUNTRY 
  ORDER BY numـcustomers DESC;'''
top_countries = pd.read_sql_query(query1 ,connection)

# %%
top_countries.head()
# Out:
#    Country  numـcustomers  sum(total)
# 0      USA             13      523.06
# 1   Canada              8      303.96
# 2   France              5      195.10
# 3   Brazil              5      190.10
# 4  Germany              4      156.48

# %%
plt.figure(figsize=[20,8])

plt.suptitle('Top Countries',fontsize = 24)

plt.subplot(1,2,1) 
plt.bar(top_countries['Country'][0:5],top_countries['sum(total)'][0:5])
plt.title(' Number of Total Sales By Country',fontsize = 20)
plt.ylabel('Number of Total Sales',fontsize = 16)
plt.xticks( fontsize = '14', family = 'fantasy',color='k');
plt.yticks( fontsize = '18', family = 'fantasy',color='k');


plt.subplot(1,2,2)
plt.bar(top_countries['Country'][0:5],top_countries['numـcustomers'][0:5])
plt.ylabel('Number of Customers',fontsize = 16)
plt.title('Number of Customers By Country',fontsize = 20);
plt.xticks( fontsize = '14', family = 'fantasy',color='k');
plt.yticks( fontsize = '18', family = 'fantasy',color='k');

# %%
sns.relplot(x=top_countries['numـcustomers'][0:5],
y=top_countries['sum(total)'][0:5],
hue=top_countries['Country'][0:5],
size=top_countries['numـcustomers'][0:5], sizes=(50,500))
plt.xlabel('Number of Customers',fontsize = 16)
plt.ylabel('Number of Total Sale',fontsize = 16)
# Out:
# Text(16.37742187500001, 0.5, 'Number of Total Sale')

# %% [markdown]
# # Identifying Popular Music Genres

# %%
query2 = '''  SELECT DISTINCT  G.NAME  ,COUNT(  G.NAME)
  FROM CUSTOMER C
  JOIN INVOICE I ON C.CUSTOMERID = I.CUSTOMERID
  JOIN INVOICELINE IL ON IL.INVOICELINEID = I.INVOICEID
  JOIN TRACK T ON IL.TRACKID = T.TRACKID
  JOIN GENRE G ON T.GENREID = G.GENREID
   GROUP BY G.NAME
  ORDER BY COUNT(  G.NAME) DESC;'''
top_music= pd.read_sql_query(query2 ,connection)

# %%
top_music.describe()
# Out:
#        COUNT(  G.NAME)
# count        17.000000
# mean         24.235294
# std          42.569839
# min           1.000000
# 25%           2.000000
# 50%           4.000000
# 75%          19.000000
# max         160.000000

# %%
top_music.head()
# Out:
#                  Name  COUNT(  G.NAME)
# 0                Rock              160
# 1               Latin               81
# 2               Metal               56
# 3  Alternative & Punk               56
# 4                Jazz               19

# %%
plt.figure(figsize=[20,8])
plt.suptitle('Top Popular Music',fontsize = 24)

plt.subplot(1,2,1) 
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99','#66b3ff']
plt.pie(top_music['COUNT(  G.NAME)'][0:5],labels= top_music['Name'][0:5],colors=colors);
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.figure(figsize=[20,8])


plt.subplot(1,2,2) 
plt.bar(top_music['Name'][0:5],top_music['COUNT(  G.NAME)'][0:5], color = ['#ff9999','#66b3ff','#99ff99','#ffcc99','#66b3ff'])
plt.title(' Top Popular Music By sales',fontsize = 20)
plt.ylabel('Sales',fontsize = 16)
plt.xticks( fontsize = '14', family = 'fantasy',color='k');
plt.yticks( fontsize = '18', family = 'fantasy',color='k');

# %% [markdown]
# # Identifying Popular Artist by Top Music Genres

# %%
query3 = '''SELECT ar.name artistname, COUNT(al.albumid) albums_sold
FROM  Artist  ar
INNER JOIN album al ON ar.artistid = al.artistid
INNER JOIN track t ON t.albumid = al.albumid
INNER JOIN genre g ON t.genreid = g.genreid
WHERE g.name = "Rock" or "Latin" or "Metal" or "Alternative & Punk" or "Jazz"
GROUP BY  artistname
ORDER BY albums_sold DESC
LIMIT 5;'''
top_artist= pd.read_sql_query(query3 ,connection)

# %%
top_artist.head()
# Out:
#      artistname  albums_sold
# 0  Led Zeppelin          114
# 1            U2          112
# 2   Deep Purple           92
# 3   Iron Maiden           81
# 4     Pearl Jam           54

# %%
plt.grid()
plt.plot(top_artist['artistname'],top_artist['albums_sold'])
plt.scatter(top_artist['artistname'],top_artist['albums_sold']);
plt.xticks( fontsize = '10', family = 'fantasy',color='gray');
plt.yticks( fontsize = '10', family = 'fantasy',color='gray');
